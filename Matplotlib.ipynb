# %% [markdown]
# <a href="https://colab.research.google.com/github/NO26song/NO26song/blob/main/Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 한글 깨짐현상
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# fonts-nanum is already the newest version (20170925-1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 10 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %%
# import matplotlib.font_manager as fm
# fm.fontManager.ttflist #사용 가능한 폰트 확인
# matplotlib.rcParams['font.size'] = 15 #글자크기
# matplotlib.rcParams['axes.unicode_minus'] = False

# %%
import matplotlib.pyplot as plt

plt.rc('font', family='NanumBarunGothic')

# %% [markdown]
# # Matplotlib
# 다양한 형태의 그래프를 통해서 데이터 시각화를 할 수 있는 라이브러리

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## 01.그래프 기본

# %%
x = [1,2,3]
y = [2,4,6]
plt.plot(x,y)
plt.show()

# %% [markdown]
# ## Title 설정

# %%
plt.plot(x,y)
plt.title("꺽은선 그래프")
# Out:
# Text(0.5, 1.0, '꺽은선 그래프')

# %%
plt.plot([-1,0,1],[-4,0,4])
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# ## 02.축

# %%
x = [1,2,3]
y = [2,4,8]

# %%
plt.plot(x,y)
#plt.title('꺾은선 그래프',fontdict={'family':'HYGungSo-Bold','size':20}) #개발 폰트 설정
plt.title('꺽은선 그래프')
# Out:
# Text(0.5, 1.0, '꺽은선 그래프')

# %%
plt.plot(x,y)
plt.xlabel('X축')
plt.ylabel('Y축')
# Out:
# Text(0, 0.5, 'Y축')

# %%
plt.plot(x,y)
plt.xlabel('X축',color='red')
plt.ylabel('Y축',color = '#00aa00')
# Out:
# Text(0, 0.5, 'Y축')

# %%
plt.plot(x,y)
plt.xticks([1,2,3])
plt.yticks([3,6,9,12])
plt.show()

# %% [markdown]
# ## 03.범례(legend)

# %%
plt.plot(x,y,label='무슨 데이터')
plt.legend()

# %%
plt.plot(x,y,label='무슨 데이터')
plt.legend(loc= 'upper right')

# %%
plt.plot(x,y,label='무슨 데이터')
plt.legend(loc= (0.5,0.5))

# %% [markdown]
# ## 04.스타일

# %%
plt.plot(x,y,linewidth=5) #라인 두께

# %%
plt.plot(x,y,marker='o')

# %%
plt.plot(x,y,marker='o',linestyle='None')

# %%
plt.plot(x,y,marker='v',markersize=10)

# %%
plt.plot(x,y,marker='X',markersize=10)

# %%
#matplotlib marker 구글 검색

# %%
plt.plot(x,y,marker='X',markeredgecolor='red',markerfacecolor='yellow',markersize=20)

# %% [markdown]
# ###선스타일

# %%
plt.plot(x,y,linestyle=':')

# %%
plt.plot(x,y,linestyle='--')

# %%
plt.plot(x,y,linestyle='-.')

# %% [markdown]
# ###색깔

# %%
plt.plot(x,y,color='pink')

# %%
plt.plot(x,y,color='b')

# %%
# matplotlib color 구글 검색

# %% [markdown]
# ### 포맷

# %%
plt.plot(x,y,'ro--') # r : color,0 : marker,-- : linestyle

# %%
plt.plot(x,y,'go')

# %% [markdown]
# ###축약어

# %%
plt.plot(x,y, marker='o',mfc='red',ms=10,mec='blue',ls=':')

# %%
# matplotlib markerfacecolor mfc 구글 검색

# %% [markdown]
# ### 투명도

# %%
plt.plot(x,y,marker='o',mfc='red',ms=10,alpha=0.3) #alpha: 투명도(0~1)

# %% [markdown]
# ### 그래프 크기

# %%
plt.figure(figsize=(10,15))
plt.plot(x,y)

# %%
plt.figure(figsize=(10,5),dpi=150)
plt.plot(x,y)

# %% [markdown]
# ###배경색

# %%
plt.figure(facecolor='b')
plt.plot(x,y)

# %% [markdown]
# ## 05.파일 저장

# %%
plt.plot(x,y)
plt.savefig('graph.png',dpi=100)

# %%
plt.figure(dpi=200)
plt.plot(x,y)
plt.savefig('graph_200.png',dpi=100) #화면엔 dpi=200으로 보이나, 저장은 dpi=100으로 저장됌

# %% [markdown]
# ## 06.텍스트

# %%
plt.plot(x,y,marker='o')
for idx, txt in enumerate(y):
    plt.text(x[idx],y[idx]+0.3,txt,ha='center',color='red')

# %% [markdown]
# ### 07.여러데이터

# %% [markdown]
# ### covid-19 백신 종류별 접종 인구

# %%
days = [1,2,3]
az = [2,4,8] # 단위 만명
pfizer = [5,1,3]
moderna = [1,2,5]

plt.plot(days,az)
plt.plot(days,pfizer)
plt.plot(days,moderna)

# %%
plt.plot(days,az,label='az')
plt.plot(days,pfizer,label='pfizer',marker='o',linestyle='--')
plt.plot(days,moderna,label='moderna',marker='s',ls='-.')

plt.legend()

# %%
plt.plot(days,az,label='az')
plt.plot(days,pfizer,label='pfizer',marker='o',linestyle='--')
plt.plot(days,moderna,label='moderna',marker='s',ls='-.')

plt.legend(ncol=3)

# %% [markdown]
# ## 08.막대그래프(기본)

# %%
labels= ['강백호','서태웅','정대만'] #이름
values = [190,187,184]
plt.bar(labels,values)
# Out:
# <BarContainer object of 3 artists>

# %%
labels= ['강백호','서태웅','정대만'] 
values = [190,187,184]
plt.bar(labels,values,color='red')
# Out:
# <BarContainer object of 3 artists>

# %%
labels= ['강백호','서태웅','정대만'] #이름
values = [190,187,184]
colors=['r','g','b']
plt.bar(labels,values,color=colors,alpha=0.5)
# Out:
# <BarContainer object of 3 artists>

# %%
labels= ['강백호','서태웅','정대만'] #이름
values = [190,187,184]

plt.bar(labels,values)
plt.ylim(175,195)
# Out:
# (175.0, 195.0)

# %%
plt.bar(labels,values,width=0.5)
# Out:
# <BarContainer object of 3 artists>

# %%
plt.bar(labels,values,width=0.3)
plt.xticks(rotation=45)
plt.yticks(rotation=45)
# Out:
# (array([  0.,  25.,  50.,  75., 100., 125., 150., 175., 200.]),
#  <a list of 9 Text major ticklabel objects>)

# %%
ticks = ['1번학생','2번학생','3번학생']

plt.bar(labels,values)
plt.xticks(labels,ticks)
# Out:
# ([<matplotlib.axis.XTick at 0x7f545ce32450>,
#   <matplotlib.axis.XTick at 0x7f545ce32dd0>,
#   <matplotlib.axis.XTick at 0x7f545d0bd290>],
#  [Text(0, 0, '1번학생'), Text(0, 0, '2번학생'), Text(0, 0, '3번학생')])

# %% [markdown]
# ## 09.막대그래프(심화)

# %%
labels= ['강백호','서태웅','정대만'] #이름
values = [190,187,184]
plt.barh(labels,values)
plt.xlim(175,195)
# Out:
# (175.0, 195.0)

# %%
bar = plt.bar(labels,values)
bar[0].set_hatch('/')
bar[1].set_hatch('x')
bar[2].set_hatch('..')

# %%
## matplotlib hatch 구글 검색

# %%
bar = plt.bar(labels,values)

for idx,rect in enumerate(bar):
    plt.text(idx,rect.get_height() + 3,values[idx],ha='center',color='red')

# %% [markdown]
# ## 10.DataFrame 활용

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame({'지원번호':['1번','2번','3번','4번','5번','6번','7번','8번'],
                   '이름':['채치수','정대만','송태섭','서태웅','강백호','번덕규','황태산','윤대협'],
                   '학교':['북산고','북산고','북산고','북산고','북산고','능남고','능남고','능남고'],
                   '키':[197,184,168,187,188,202,188,190],
                   '국어':[90,40,80,40,15,80,55,100],
                   '영어':[85,35,75,60,20,100,65,85],
                   '수학':[100,50,70,70,10,95,45,90],
                   '과학':[95,55,80,75,35,85,40,95],
                   '사회':[85,25,75,80,10,80,35,95],
                   'sw특기':['python','java','javascript',np.nan,np.nan,'c','python','c#']})
df
# Out:
#   지원번호   이름   학교    키   국어   영어   수학  과학  사회        sw특기
# 0   1번  채치수  북산고  197   90   85  100  95  85      python
# 1   2번  정대만  북산고  184   40   35   50  55  25        java
# 2   3번  송태섭  북산고  168   80   75   70  80  75  javascript
# 3   4번  서태웅  북산고  187   40   60   70  75  80         NaN
# 4   5번  강백호  북산고  188   15   20   10  35  10         NaN
# 5   6번  번덕규  능남고  202   80  100   95  85  80           c
# 6   7번  황태산  능남고  188   55   65   45  40  35      python
# 7   8번  윤대협  능남고  190  100   85   90  95  95          c#

# %%
plt.plot(df['지원번호'],df['키'])

# %%
plt.plot(df['지원번호'],df['영어'])
plt.plot(df['지원번호'],df['수학'])

plt.grid()

# %%
plt.plot(df['지원번호'],df['영어'])
plt.plot(df['지원번호'],df['수학'])

plt.grid(axis='y',color='purple',ls='--',linewidth=1)

# %% [markdown]
# ## 11.누적막대그래프

# %%
plt.bar(df['이름'],df['국어'])
plt.bar(df['이름'],df['영어'])
# Out:
# <BarContainer object of 8 artists>

# %%
plt.bar(df['이름'],df['국어'])
plt.bar(df['이름'],df['영어'],bottom = df['국어'])
# Out:
# <BarContainer object of 8 artists>

# %%
plt.bar(df['이름'],df['국어'])
plt.bar(df['이름'],df['영어'],bottom = df['국어'])
plt.bar(df['이름'],df['수학'],bottom = df['국어']+df['영어'])
# Out:
# <BarContainer object of 8 artists>

# %%
plt.bar(df['이름'],df['국어'],label='국어')
plt.bar(df['이름'],df['영어'],bottom = df['국어'],label='영어')
plt.bar(df['이름'],df['수학'],bottom = df['국어']+df['영어'],label='수학')

plt.xticks(rotation=60)
plt.legend()

# %% [markdown]
# ## 12.다중 막대그래프

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame({'지원번호':['1번','2번','3번','4번','5번','6번','7번','8번'],
                   '이름':['채치수','정대만','송태섭','서태웅','강백호','번덕규','황태산','윤대협'],
                   '학교':['북산고','북산고','북산고','북산고','북산고','능남고','능남고','능남고'],
                   '키':[197,184,168,187,188,202,188,190],
                   '국어':[90,40,80,40,15,80,55,100],
                   '영어':[85,35,75,60,20,100,65,85],
                   '수학':[100,50,70,70,10,95,45,90],
                   '과학':[95,55,80,75,35,85,40,95],
                   '사회':[85,25,75,80,10,80,35,95],
                   'sw특기':['python','java','javascript',np.nan,np.nan,'c','python','c#']})
df
# Out:
#   지원번호   이름   학교    키   국어   영어   수학  과학  사회        sw특기
# 0   1번  채치수  북산고  197   90   85  100  95  85      python
# 1   2번  정대만  북산고  184   40   35   50  55  25        java
# 2   3번  송태섭  북산고  168   80   75   70  80  75  javascript
# 3   4번  서태웅  북산고  187   40   60   70  75  80         NaN
# 4   5번  강백호  북산고  188   15   20   10  35  10         NaN
# 5   6번  번덕규  능남고  202   80  100   95  85  80           c
# 6   7번  황태산  능남고  188   55   65   45  40  35      python
# 7   8번  윤대협  능남고  190  100   85   90  95  95          c#

# %%
import numpy as np
np.arange(5),np.arange(3,6)
# Out:
# (array([0, 1, 2, 3, 4]), array([3, 4, 5]))

# %%
arr =  np.arange(5)
arr
# Out:
# array([0, 1, 2, 3, 4])

# %%
arr + 100
# Out:
# array([100, 101, 102, 103, 104])

# %%
N = df.shape[0]
N
# Out:
# 8

# %%
index = np.arange(N)
index
# Out:
# array([0, 1, 2, 3, 4, 5, 6, 7])

# %%
w = 0.25
plt.bar(index - w,df['국어'])
plt.bar(index,df['영어'])
plt.bar(index + w,df['수학'])
# Out:
# <BarContainer object of 8 artists>

# %%
w = 0.25
plt.bar(index - w,df['국어'],width=w,label='국어')
plt.bar(index,df['영어'],width=w,label='영어')
plt.bar(index + w,df['수학'],width=w,label='수학')
plt.legend(ncol=3)

# %%
plt.figure(figsize=(10,5))
plt.title('학생별 성적')

w = 0.25
plt.bar(index - w,df['국어'],width=w,label='국어')
plt.bar(index,df['영어'],width=w,label='영어')
plt.bar(index + w,df['수학'],width=w,label='수학')
plt.legend(ncol=3)
plt.xticks(index,df['이름'])
# Out:
# ([<matplotlib.axis.XTick at 0x7fda4ef9b350>,
#   <matplotlib.axis.XTick at 0x7fda4ef9bfd0>,
#   <matplotlib.axis.XTick at 0x7fda4ef9bc50>,
#   <matplotlib.axis.XTick at 0x7fda4ef16210>,
#   <matplotlib.axis.XTick at 0x7fda4ef16710>,
#   <matplotlib.axis.XTick at 0x7fda4ef16c50>,
#   <matplotlib.axis.XTick at 0x7fda4ef16b90>,
#   <matplotlib.axis.XTick at 0x7fda4ef1e150>],
#  [Text(0, 0, '채치수'),
#   Text(0, 0, '정대만'),
#   Text(0, 0, '송태섭'),
#   Text(0, 0, '서태웅'),
#   Text(0, 0, '강백호'),
#   Text(0, 0, '번덕규'),
#   Text(0, 0, '황태산'),
#   Text(0, 0, '윤대협')])

# %% [markdown]
# ## 13.원 그래프(기본)

# %%
values = [30,25,20,13,10,2]
labels = ['Python','Java','Javascript','c#','c/c++','ETC']

plt.pie(values,labels=labels,autopct="%.1f%%")
plt.show()

# %%
values = [30,25,20,13,10,2]
labels = ['Python','Java','Javascript','c#','c/c++','ETC']

plt.pie(values,labels=labels,autopct="%.1f%%",startangle=90)
plt.show()

# %%
values = [30,25,20,13,10,2]
labels = ['Python','Java','Javascript','c#','c/c++','ETC']

plt.pie(values,labels=labels,autopct="%.1f%%",startangle=90,counterclock=False)
plt.show()

# %%
values = [30,25,20,13,10,2]
labels = ['Python','Java','Javascript','c#','c/c++','ETC']
# explode = [0.2,0.1,0,0,0,0]
explode = [0.05] * 6
plt.pie(values,labels=labels ,explode=explode)
# Out:
# ([<matplotlib.patches.Wedge at 0x7fda4ebc5b10>,
#   <matplotlib.patches.Wedge at 0x7fda4ebc5f50>,
#   <matplotlib.patches.Wedge at 0x7fda4eb514d0>,
#   <matplotlib.patches.Wedge at 0x7fda4eb51590>,
#   <matplotlib.patches.Wedge at 0x7fda4eb5b450>,
#   <matplotlib.patches.Wedge at 0x7fda4eb5ba90>],
#  [Text(0.6759530052933503, 0.9303695688461054, 'Python'),
#   Text(-1.0246575419218258, 0.5220889979521903, 'Java'),
#   Text(-0.6759529617396072, -0.9303696004897478, 'Javascript'),
#   Text(0.45672015723488874, -1.0554177836171508, 'c#'),
#   Text(1.0405511438020287, -0.4896461141807315, 'c/c++'),
#   Text(1.1477307428644477, -0.07220901525310541, 'ETC')])

# %%
plt.pie(values,labels = labels, explode=explode)
plt.title('언어별 선호도')
plt.legend(loc=(1.2,0.3),title='언어별 선호도')
plt.show()

# %% [markdown]
# ## 14,원그래프(심화)

# %%
values = [30,25,20,13,10,2]
labels = ['Python','Java','Javascript','c#','c/c++','ETC']
colors = ['b','g','r','c','m','y']
explode = [0.05] * 6
plt.pie(values,labels=labels,autopct="%.1f%%",colors=colors,startangle=90,counterclock=False,
        explode=explode)
plt.show()

# %%
values = [30,25,20,13,10,2]
wedgeprops = {'width':0.8}
labels = ['Python','Java','Javascript','c#','c/c++','ETC']
colors = ['b','g','r','c','m','y']
explode = [0.05] * 6
plt.pie(values,labels=labels,
        autopct="%.1f%%",
        colors=colors,
        startangle=90,
        counterclock=False,
        explode=explode,
        wedgeprops=wedgeprops)
plt.show()

# %%
wedgeprops = {'width':0.6,'edgecolor':'w','linewidth':3}
plt.pie(values,labels=labels,
        autopct="%.1f%%",
        colors=colors,
        startangle=90,
        counterclock=False,
        #explode=explode,
        wedgeprops=wedgeprops)
plt.show()

# %%
def custom_autopct(pct):
     return ("%.1f%%" % pct) if pct >= 10 else ''
plt.pie(values,labels=labels,
        autopct=custom_autopct,
        colors=colors,
        startangle=90,
        counterclock=False,
        #explode=explode,
        wedgeprops=wedgeprops,)
plt.show()

# %% [markdown]
# ###DataFrame활용

# %%
df
# Out:
#   지원번호   이름   학교    키   국어   영어   수학  과학  사회        sw특기
# 0   1번  채치수  북산고  197   90   85  100  95  85      python
# 1   2번  정대만  북산고  184   40   35   50  55  25        java
# 2   3번  송태섭  북산고  168   80   75   70  80  75  javascript
# 3   4번  서태웅  북산고  187   40   60   70  75  80         NaN
# 4   5번  강백호  북산고  188   15   20   10  35  10         NaN
# 5   6번  번덕규  능남고  202   80  100   95  85  80           c
# 6   7번  황태산  능남고  188   55   65   45  40  35      python
# 7   8번  윤대협  능남고  190  100   85   90  95  95          c#

# %%
grp = df.groupby('학교')
grp

# %%
grp.size()['북산고']
# Out:
# 5

# %%
values = [grp.size()['북산고'],grp.size()['능남고']]
labels = ['북산고','능남고']

plt.pie(values, labels=labels)
plt.title('소속 학교')
plt.show()

# %% [markdown]
# ## 15.산점도

# %%
df['학년'] = [3,3,2,1,1,3,2,2]
df
# Out:
#   지원번호   이름   학교    키   국어   영어   수학  과학  사회        sw특기  학년
# 0   1번  채치수  북산고  197   90   85  100  95  85      python   3
# 1   2번  정대만  북산고  184   40   35   50  55  25        java   3
# 2   3번  송태섭  북산고  168   80   75   70  80  75  javascript   2
# 3   4번  서태웅  북산고  187   40   60   70  75  80         NaN   1
# 4   5번  강백호  북산고  188   15   20   10  35  10         NaN   1
# 5   6번  번덕규  능남고  202   80  100   95  85  80           c   3
# 6   7번  황태산  능남고  188   55   65   45  40  35      python   2
# 7   8번  윤대협  능남고  190  100   85   90  95  95          c#   2

# %%
plt.scatter(df['영어'],df['수학'])
plt.xlabel('영어 점수')
plt.ylabel('수학 점수')
# Out:
# Text(0, 0.5, '수학 점수')

# %%
sizes = np.random.rand(8) * 1000
sizes
# Out:
# array([818.76644941,  84.71070637, 673.71949716, 630.93600555,
#        998.76491831, 655.52368935, 318.17946723, 662.77611723])

# %%
plt.scatter(df['영어'],df['수학'],s=sizes)
plt.xlabel('영어 점수')
plt.ylabel('수학 점수')
# Out:
# Text(0, 0.5, '수학 점수')

# %%
sizes = df['학년'] * 500
plt.scatter(df['영어'],df['수학'],s=sizes,c=df['학년'],cmap='viridis')
plt.xlabel('영어 점수')
plt.ylabel('수학 점수')
# Out:
# Text(0, 0.5, '수학 점수')

# %%
plt.figure(figsize=(10,10))

plt.scatter(df['영어'],df['수학'],s=sizes,c=df['학년'],cmap='viridis')
plt.xlabel('영어 점수')
plt.ylabel('수학 점수')
plt.colorbar(ticks=[1,2,3],label='학년',shrink=0.3)

# %%
plt.figure(figsize=(10,10))

plt.scatter(df['영어'],df['수학'],s=sizes,c=df['학년'],cmap='viridis')
plt.xlabel('영어 점수')
plt.ylabel('수학 점수')
plt.colorbar(ticks=[1,2,3],label='학년',shrink=0.5,orientation='horizontal')

# %% [markdown]
# ## 16.여러 그래프

# %%
fig,axs = plt.subplots(2,2,figsize=(15,10))
fig.suptitle('여러 그래프 넣기')

#첫번째 그래프
axs[0,0].bar(df['이름'],df['국어'],label='국어점수')
axs[0,0].set_title('첫 번째 그래프') #제목
axs[0,0].legend() #범례
axs[0,0].set(xlabel='이름',ylabel='점수') # x,y축 label
axs[0,0].set_facecolor('lightyellow') # 전면 색
axs[0,0].grid(linestyle='--',linewidth=0.5)

#두 번째 그래프
axs[0,1].plot(df['이름'],df['수학'],label='수학')
axs[0,1].plot(df['이름'],df['영어'],label='영어')
axs[0,1].legend()

#세번째 그래프
axs[1,0].barh(df['이름'],df['키'])

#네번째 그래프
axs[1,1].plot(df['이름'],df['사회'],color='green',alpha=0.5)

# %% [markdown]
# # 퀴즈

# %%
import pandas as pd
#import matplotlib.pyplot as plt
import matplotlib
# matplotlib.rcParams['font.family'] = 'Malgun Gothic' # Windows
# # matplotlib.rcParams['font.family'] = 'AppleGothic' # Mac
# matplotlib.rcParams['font.size'] = 15
# matplotlib.rcParams['axes.unicode_minus'] = False

data = {
    '영화' : ['명량', '극한직업', '신과함께-죄와 벌', '국제시장', '괴물', '도둑들', '7번방의 선물', '암살'],
    '개봉 연도' : [2014, 2019, 2017, 2014, 2006, 2012, 2013, 2015],
    '관객 수' : [1761, 1626, 1441, 1426, 1301, 1298, 1281, 1270], # (단위 : 만 명)
    '평점' : [8.88, 9.20, 8.73, 9.16, 8.62, 7.64, 8.83, 9.10]
}
df = pd.DataFrame(data)
df
# Out:
#           영화  개봉 연도  관객 수    평점
# 0         명량   2014  1761  8.88
# 1       극한직업   2019  1626  9.20
# 2  신과함께-죄와 벌   2017  1441  8.73
# 3       국제시장   2014  1426  9.16
# 4         괴물   2006  1301  8.62
# 5        도둑들   2012  1298  7.64
# 6    7번방의 선물   2013  1281  8.83
# 7         암살   2015  1270  9.10

# %% [markdown]
# ## 1) 영화데이터를 활용하여 x 축은 영화, y축은 평점인 막대 그래프를 만드시오.

# %%
plt.bar(df['영화'],df['평점'])
# Out:
# <BarContainer object of 8 artists>

# %% [markdown]
# ## 2) 앞에서 만든 막대 그래프에 제시된 세부 사항을 적용하시오.
#
# - 제목:국내 top8 영화 평점 정보
# - x축 label: 영화(90도회전)
# - y축 label: 평점

# %%
plt.bar(df['영화'],df['평점'])
plt.title('국내 Top 8 영화 평점 정보')
plt.xlabel('영화')
plt.xticks(rotation=90)
plt.ylabel('평점')
# Out:
# Text(0, 0.5, '평점')

# %% [markdown]
# ## 3)개봉 연도별 평점 변화 추이를 꺾은선 그래프로 그리시오.
#
# 연도별 평균 데이터를 구하는 코드는 다음과 같습니다.

# %%
df_group = df.groupby('개봉 연도').mean()
df_group
# Out:
#          관객 수    평점
# 개봉 연도
# 2006   1301.0  8.62
# 2012   1298.0  7.64
# 2013   1281.0  8.83
# 2014   1593.5  9.02
# 2015   1270.0  9.10
# 2017   1441.0  8.73
# 2019   1626.0  9.20

# %%
plt.plot(df_group.index,df_group['평점'])

# %% [markdown]
# ## 4)앞에서 만든 그래프에 제시된 세부 사항을 적용하시오.
#
# - marker:'o'
# - x축 눈금 : 5년 단위(2005,2010,2015,2020)
# - y축 범위: 최소7,최대 10

# %%
import numpy as np
plt.plot(df_group.index,df_group['평점'],marker='o')
plt.xticks([2005,2010,2015,2020])
plt.ylim(7,10)
# Out:
# (7.0, 10.0)

# %% [markdown]
# ## 5) 평점이 9점 이상인 영화의 비율을 확인할 수 있는 원 그래프르 제시된 세부 사항을 적용하여 그리시오.
#
# - label:9점 이상 /9점미만
# - 퍼센트: 소수점 첫째자리까지 표시
# - 범례: 그래프 우측에 표시

# %%
filt = df['평점'] >= 9.0
values = [len(df[filt]),len(df[-filt])]
labels = ['9점 이상','9점 미만']

plt.pie(values,labels=labels,autopct='%.1f%%')
plt.legend(loc=(1,0.5))
plt.show()
